# %%
import docker
import uuid
import paramiko
import os
from timeit import default_timer as timer

def run_in_master(command):
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect("namenode", username="root", password="pass")
    ssh_stdin, ssh_stdout, ssh_stderr = ssh.exec_command(f"cd /app/ && . env_var.sh && {command}")
    return (ssh_stdout.readlines(), ssh_stderr.readlines())

def get_data_from_output_path(path):
    return f"{path}/part-r-00000"

def print_hdfs_output(path):
    raw = run_in_master(f"hdfs dfs -cat {get_data_from_output_path(path)}")[0]
    print(raw[0:1000])

# %% [markdown]
# # Covid

# %% [markdown]
# ## Wybór kolumn

# %%
covid_01_jar_path = "/data/master_volume/map_reduce_jars/covid_01.jar"
covid_01_input_path = "/datasets/covid-dataset.jsonl"
covid_01_output_path = "/out_covid_1" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {covid_01_jar_path} {covid_01_input_path} {covid_01_output_path}")
print(res)
# Out:
# ([], ['2023-05-20 09:32:02,967 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.20.0.6:8032\n', '2023-05-20 09:32:03,031 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.20.0.7:10200\n', '2023-05-20 09:32:03,166 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-20 09:32:03,179 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684575065428_0001\n', '2023-05-20 09:32:03,353 INFO input.FileInputFormat: Total input files to process : 1\n', '2023-05-20 09:32:03,419 INFO mapreduce.JobSubmitter: number of splits:5\n', '2023-05-20 09:32:03,497 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684575065428_0001\n', '2023-05-20 09:32:03,498 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-20 09:32:03,575 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-20 09:32:03,575 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-20 09:32:03,872 INFO impl.YarnClientImpl: Submitted application application_1684575065428_0001\n', '2023-05-20 09:32:03,917 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684575065428_0001/\n', '2023-05-20 09:32:03,918 INFO mapreduce.Job: Running job: job_1684575065428_0001\n', '2023-05-20 09:32:07,955 INFO mapreduce.Job: Job job_1684575065428_0001 running in uber mode : false\n', '2023-05-20 09:32:07,956 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-20 09:32:17,024 INFO mapreduce.Job:  map 40% reduce 0%\n', '2023-05-20 09:32:18,027 INFO mapreduce.Job:  map 60% reduce 0%\n', '2023-05-20 09:32:21,035 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-20 09:32:33,062 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-20 09:34:00,246 INFO mapreduce.Job: Job job_1684575065428_0001 completed successfully\n', '2023-05-20 09:34:00,308 INFO mapreduce.Job: Counters: 55\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=4290362\n', '\t\tFILE: Number of bytes written=10235973\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=630678253\n', '\t\tHDFS: Number of bytes written=50889345\n', '\t\tHDFS: Number of read operations=20\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tKilled map tasks=1\n', '\t\tLaunched map tasks=5\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=5\n', '\t\tTotal time spent by all maps in occupied slots (ms)=103704\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=807584\n', '\t\tTotal time spent by all map tasks (ms)=25926\n', '\t\tTotal time spent by all reduce tasks (ms)=100948\n', '\t\tTotal vcore-milliseconds taken by all map tasks=25926\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=100948\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=106192896\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=826966016\n', '\tMap-Reduce Framework\n', '\t\tMap input records=304394\n', '\t\tMap output records=304394\n', '\t\tMap output bytes=47798274\n', '\t\tMap output materialized bytes=4290140\n', '\t\tInput split bytes=570\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=1\n', '\t\tReduce shuffle bytes=4290140\n', '\t\tReduce input records=304394\n', '\t\tReduce output records=304394\n', '\t\tSpilled Records=608788\n', '\t\tShuffled Maps =5\n', '\t\tFailed Shuffles=0\n', '\t\tMerged Map outputs=5\n', '\t\tGC time elapsed (ms)=993\n', '\t\tCPU time spent (ms)=45680\n', '\t\tPhysical memory (bytes) snapshot=5042634752\n', '\t\tVirtual m ...

# %%
print_hdfs_output(covid_01_output_path)
# Out:
# ['id\t{"date":"2023-04-19","country":"Zimbabwe","total_cases":264613,"new_cases":0,"total_deaths":264613,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-18","country":"Zimbabwe","total_cases":264613,"new_cases":0,"total_deaths":264613,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-17","country":"Zimbabwe","total_cases":264613,"new_cases":3,"total_deaths":264613,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-16","country":"Zimbabwe","total_cases":264610,"new_cases":3,"total_deaths":264610,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-15","country":"Zimbabwe","total_cases":264607,"new_cases":10,"total_deaths":264607,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-14","country":"Zimbabwe","total_cases":264597,"new_cases":4,"total_deaths":264597,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-13","country":"Zimbabwe","total_cases":264593,"new_cases":2,"total_deaths":264593,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-12","country":"Zimbabwe","total_cases":264591,"new_cases":5,"total_deaths":264591,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-11","country":"Zimbabwe","total_cases":264586,"new_cases":2,"total_deaths":264586,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-10","country":"Zimbabwe","total_cases":264584,"new_cases":2,"total_deaths":264584,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-09","country":"Zimbabwe","total_cases":264582,"new_cases":4,"total_deaths":264582,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-08","country":"Zimbabwe","total_cases":264578,"new_cases":2,"total_deaths":264578,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-07","country":"Zimbabwe","total_cases":264576,"new_cases":5,"total_deaths":264576,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-06","country":"Zimbabwe","total_cases":264571,"new_cases":5,"total_deaths":264571,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-05","country":"Zimbabwe","total_cases":264566,"new_cases":4,"total_deaths":264566,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-04","country":"Zimbabwe","total_cases":264562,"new_cases":7,"total_deaths":264562,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-03","country":"Zimbabwe","total_cases":264555,"new_cases":6,"total_deaths":264555,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-02","country":"Zimbabwe","total_cases":264549,"new_cases":0,"total_deaths":264549,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-04-01","country":"Zimbabwe","total_cases":264549,"new_cases":7,"total_deaths":264549,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-03-31","country":"Zimbabwe","total_cases":264542,"new_cases":7,"total_deaths":264542,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-03-30","country":"Zimbabwe","total_cases":264535,"new_cases":5,"total_deaths":264535,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-03-29","country":"Zimbabwe","total_cases":264530,"new_cases":9,"total_deaths":264530,"new_deaths":0,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023-03-28","country":"Zimbabwe","total_cases":264521,"new_cases":10,"total_deaths":264521,"new_deaths":1,"average_global_new_cases_per_million":160.28056}\n', 'id\t{"date":"2023 ...

# %% [markdown]
# ## Wybór wymiaru czasu

# %%
covid_02_jar_path = "/data/master_volume/map_reduce_jars/covid_02.jar"
covid_02_input_path = get_data_from_output_path(covid_01_output_path)
covid_02_output_path = "/out_covid_2" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {covid_02_jar_path} {covid_02_input_path} {covid_02_output_path}")
print(res)

# %%
print_hdfs_output(covid_02_output_path)
# Out:
# ['id\t{"date":"2021-11-02"}\n', 'id\t{"date":"2021-11-03"}\n', 'id\t{"date":"2021-11-04"}\n', 'id\t{"date":"2021-11-05"}\n', 'id\t{"date":"2021-11-06"}\n', 'id\t{"date":"2021-11-07"}\n', 'id\t{"date":"2021-11-08"}\n', 'id\t{"date":"2021-11-09"}\n', 'id\t{"date":"2021-11-10"}\n', 'id\t{"date":"2021-11-11"}\n', 'id\t{"date":"2021-11-12"}\n', 'id\t{"date":"2021-11-13"}\n', 'id\t{"date":"2021-11-14"}\n', 'id\t{"date":"2021-11-15"}\n', 'id\t{"date":"2021-11-16"}\n', 'id\t{"date":"2021-11-17"}\n', 'id\t{"date":"2021-11-18"}\n', 'id\t{"date":"2021-11-19"}\n', 'id\t{"date":"2021-11-20"}\n', 'id\t{"date":"2021-11-21"}\n', 'id\t{"date":"2021-11-22"}\n', 'id\t{"date":"2021-11-23"}\n', 'id\t{"date":"2021-11-24"}\n', 'id\t{"date":"2021-11-25"}\n', 'id\t{"date":"2021-11-26"}\n', 'id\t{"date":"2021-11-27"}\n', 'id\t{"date":"2021-11-28"}\n', 'id\t{"date":"2021-11-29"}\n', 'id\t{"date":"2021-11-30"}\n', 'id\t{"date":"2021-12-01"}\n', 'id\t{"date":"2021-12-02"}\n', 'id\t{"date":"2021-12-03"}\n', 'id\t{"date":"2021-12-04"}\n', 'id\t{"date":"2021-12-05"}\n', 'id\t{"date":"2021-12-06"}\n', 'id\t{"date":"2021-12-07"}\n', 'id\t{"date":"2021-12-08"}\n', 'id\t{"date":"2021-12-09"}\n', 'id\t{"date":"2021-12-10"}\n', 'id\t{"date":"2021-12-11"}\n', 'id\t{"date":"2021-12-12"}\n', 'id\t{"date":"2021-12-13"}\n', 'id\t{"date":"2021-12-14"}\n', 'id\t{"date":"2021-12-15"}\n', 'id\t{"date":"2021-12-16"}\n', 'id\t{"date":"2021-12-17"}\n', 'id\t{"date":"2021-12-18"}\n', 'id\t{"date":"2021-12-19"}\n', 'id\t{"date":"2021-12-20"}\n', 'id\t{"date":"2021-12-21"}\n', 'id\t{"date":"2021-12-22"}\n', 'id\t{"date":"2021-12-23"}\n', 'id\t{"date":"2021-12-24"}\n', 'id\t{"date":"2021-12-25"}\n', 'id\t{"date":"2021-12-26"}\n', 'id\t{"date":"2021-12-27"}\n', 'id\t{"date":"2021-12-28"}\n', 'id\t{"date":"2021-12-29"}\n', 'id\t{"date":"2021-12-30"}\n', 'id\t{"date":"2021-12-31"}\n', 'id\t{"date":"2022-01-01"}\n', 'id\t{"date":"2022-01-02"}\n', 'id\t{"date":"2022-01-03"}\n', 'id\t{"date":"2022-01-04"}\n', 'id\t{"date":"2022-01-05"}\n', 'id\t{"date":"2022-01-06"}\n', 'id\t{"date":"2022-01-07"}\n', 'id\t{"date":"2022-01-08"}\n', 'id\t{"date":"2022-01-09"}\n', 'id\t{"date":"2022-01-10"}\n', 'id\t{"date":"2022-01-11"}\n', 'id\t{"date":"2022-01-12"}\n', 'id\t{"date":"2022-01-13"}\n', 'id\t{"date":"2022-01-14"}\n', 'id\t{"date":"2022-01-15"}\n', 'id\t{"date":"2022-01-16"}\n', 'id\t{"date":"2022-01-17"}\n', 'id\t{"date":"2022-01-18"}\n', 'id\t{"date":"2022-01-19"}\n', 'id\t{"date":"2022-01-20"}\n', 'id\t{"date":"2022-01-21"}\n', 'id\t{"date":"2022-01-22"}\n', 'id\t{"date":"2022-01-23"}\n', 'id\t{"date":"2022-01-24"}\n', 'id\t{"date":"2022-01-25"}\n', 'id\t{"date":"2022-01-26"}\n', 'id\t{"date":"2022-01-27"}\n', 'id\t{"date":"2022-01-28"}\n', 'id\t{"date":"2022-01-29"}\n', 'id\t{"date":"2022-01-30"}\n', 'id\t{"date":"2022-01-31"}\n', 'id\t{"date":"2022-02-01"}\n', 'id\t{"date":"2022-02-02"}\n', 'id\t{"date":"2022-02-03"}\n', 'id\t{"date":"2022-02-04"}\n', 'id\t{"date":"2022-02-05"}\n', 'id\t{"date":"2022-02-06"}\n', 'id\t{"date":"2022-02-07"}\n', 'id\t{"date":"2022-02-08"}\n', 'id\t{"date":"2022-02-09"}\n', 'id\t{"date":"2022-02-10"}\n', 'id\t{"date":"2022-02-11"}\n', 'id\t{"date":"2022-02-12"}\n', 'id\t{"date":"2022-02-13"}\n', 'id\t{"date":"2022-02-14"}\n', 'id\t{"date":"2022-02-15"}\n', 'id\t{"date":"2022-02-16"}\n', 'id\t{"date":"2022-02-17"}\n', 'id\t{"date":"2022-02-18"}\n', 'id\t{"date":"2022-02-19"}\n', 'id\t{"date":"2022-02-20"}\n', 'id\t{"date":"2022-02-21"}\n', 'id\t{"date":"2022-02-22"}\n', 'id\t{"date":"2022-02-23"}\n', 'id\t{"date":"2022-02-24"}\n', 'id\t{"date":"2022-02-25"}\n', 'id\t{"date":"2022-02-26"}\n', 'id\t{"date":"2022-02-27"}\n', 'id\t{"date":"2022-02-28"}\n', 'id\t{"date":"2022-03-01"}\n', 'id\t{"date":"2022-03-02"}\n', 'id\t{"date":"2022-03-03"}\n', 'id\t{"date":"2022-03-04"}\n', 'id\t{"date":"2022-03-05"}\n', 'id\t{"date":"2022-03-06"}\n', 'id\t{"date":"2022-03-07"}\n', 'id\t{"date":"2022-03-08"}\n', 'id\t{"date":"2022-03-09"}\n', 'id\t{"date":"2022-03-10"}\n',  ...

# %% [markdown]
# ## Covid final

# %%
covid_03_jar_path = "/data/master_volume/map_reduce_jars/covid_03.jar"
covid_03_input_path = get_data_from_output_path(covid_01_output_path)
covid_03_output_path = "/out_covid_3" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {covid_03_jar_path} {covid_03_input_path} {covid_03_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:05:01,850 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:05:01,911 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:05:01,993 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:05:02,011 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0003\n', '2023-05-19 20:05:02,144 INFO input.FileInputFormat: Total input files to process : 1\n', '2023-05-19 20:05:02,993 INFO mapreduce.JobSubmitter: number of splits:1\n', '2023-05-19 20:05:03,071 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0003\n', '2023-05-19 20:05:03,071 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:05:03,146 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:05:03,146 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:05:03,777 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0003\n', '2023-05-19 20:05:03,801 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0003/\n', '2023-05-19 20:05:03,801 INFO mapreduce.Job: Running job: job_1684526330384_0003\n', '2023-05-19 20:05:07,836 INFO mapreduce.Job: Job job_1684526330384_0003 running in uber mode : false\n', '2023-05-19 20:05:07,836 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:05:21,888 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-19 20:05:31,911 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:05:32,916 INFO mapreduce.Job: Job job_1684526330384_0003 completed successfully\n', '2023-05-19 20:05:32,959 INFO mapreduce.Job: Counters: 54\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=27097301\n', '\t\tFILE: Number of bytes written=41197653\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=50889491\n', '\t\tHDFS: Number of bytes written=66088459\n', '\t\tHDFS: Number of read operations=8\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tLaunched map tasks=1\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=1\n', '\t\tTotal time spent by all maps in occupied slots (ms)=45024\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=60752\n', '\t\tTotal time spent by all map tasks (ms)=11256\n', '\t\tTotal time spent by all reduce tasks (ms)=7594\n', '\t\tTotal vcore-milliseconds taken by all map tasks=11256\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=7594\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=46104576\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=62210048\n', '\tMap-Reduce Framework\n', '\t\tMap input records=304394\n', '\t\tMap output records=2435152\n', '\t\tMap output bytes=454132576\n', '\t\tMap output materialized bytes=13548495\n', '\t\tInput split bytes=146\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=306187\n', '\t\tReduce shuffle bytes=13548495\n', '\t\tReduce input records=2435152\n', '\t\tReduce output records=306187\n', '\t\tSpilled Records=7305456\n', '\t\tShuffled Maps =1\n', '\t\tFailed Shuffles=0\n', '\t\tMerged Map outputs=1\n', '\t\tGC time elapsed (ms)=165\n', '\t\tCPU time spent (ms)=22770\n', '\t\tPhysical memory (bytes) snapshot=2608926720\n', '\t\tVirtual memory (bytes) snapshot=13448560640\n', '\t\tTotal committed heap usage (bytes)=2760900608\n', '\t\tPeak Map Physical memory (bytes)=999530496\n', '\t\tPeak Map Vi ...

# %%
print_hdfs_output(covid_03_output_path)
# Out:
# ['Afghanistan/2020-01-03\t{"date":"2020-01-03","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-04\t{"date":"2020-01-04","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-05\t{"date":"2020-01-05","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-06\t{"date":"2020-01-06","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-07\t{"date":"2020-01-07","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-08\t{"date":"2020-01-08","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-09\t{"date":"2020-01-09","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-10\t{"date":"2020-01-10","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-11\t{"date":"2020-01-11","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-12\t{"date":"2020-01-12","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-13\t{"date":"2020-01-13","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-14\t{"date":"2020-01-14","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-15\t{"date":"2020-01-15","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-16\t{"date":"2020-01-16","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-17\t{"date":"2020-01-17","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-18\t{"date":"2020-01-18","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-19\t{"date":"2020-01-19","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-20\t{"date":"2020-01-20","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","average_global_new_cases_per_million":160.28056}\n', 'Afghanistan/2020-01-21\t{"date":"2020-01-21","country":"Afghanistan","total_cases":0,"new_cases":0,"total_deaths":0,"new_deaths":0,"covid_spread_speed":"NaN","avera ...

# %% [markdown]
# # Steam

# %% [markdown]
# ## Agregacja danych ze źródeł Steam

# %%
steam_01_jar_path = "/data/master_volume/map_reduce_jars/steam_01_combine.jar"
steam_01_input_path = "/datasets/steam-dataset/steam_dataset/appinfo/store_data/steam_store_data.jsonl"
steam_01_input_path2 = "/datasets/steam-dataset/steam_dataset/steamspy/basic/steam_spy_scrap.jsonl"
steam_01_output_path = "/out_steam_1" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {steam_01_jar_path} {steam_01_input_path} {steam_01_input_path2} {steam_01_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:05:58,576 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:05:58,643 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:05:58,720 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:05:58,729 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0004\n', '2023-05-19 20:05:58,866 INFO input.FileInputFormat: Total input files to process : 2\n', '2023-05-19 20:05:59,726 INFO mapreduce.JobSubmitter: number of splits:6\n', '2023-05-19 20:05:59,801 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0004\n', '2023-05-19 20:05:59,801 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:05:59,884 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:05:59,884 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:06:00,515 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0004\n', '2023-05-19 20:06:00,534 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0004/\n', '2023-05-19 20:06:00,534 INFO mapreduce.Job: Running job: job_1684526330384_0004\n', '2023-05-19 20:06:04,574 INFO mapreduce.Job: Job job_1684526330384_0004 running in uber mode : false\n', '2023-05-19 20:06:04,575 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:06:20,648 INFO mapreduce.Job:  map 6% reduce 0%\n', '2023-05-19 20:06:21,651 INFO mapreduce.Job:  map 12% reduce 0%\n', '2023-05-19 20:06:22,654 INFO mapreduce.Job:  map 16% reduce 0%\n', '2023-05-19 20:06:23,667 INFO mapreduce.Job:  map 38% reduce 0%\n', '2023-05-19 20:06:26,675 INFO mapreduce.Job:  map 50% reduce 0%\n', '2023-05-19 20:06:27,678 INFO mapreduce.Job:  map 62% reduce 0%\n', '2023-05-19 20:06:28,680 INFO mapreduce.Job:  map 67% reduce 0%\n', '2023-05-19 20:06:29,683 INFO mapreduce.Job:  map 79% reduce 0%\n', '2023-05-19 20:06:30,686 INFO mapreduce.Job:  map 86% reduce 0%\n', '2023-05-19 20:06:32,691 INFO mapreduce.Job:  map 88% reduce 0%\n', '2023-05-19 20:06:38,704 INFO mapreduce.Job:  map 91% reduce 0%\n', '2023-05-19 20:06:42,713 INFO mapreduce.Job:  map 91% reduce 28%\n', '2023-05-19 20:06:44,717 INFO mapreduce.Job:  map 100% reduce 28%\n', '2023-05-19 20:06:46,721 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:06:47,727 INFO mapreduce.Job: Job job_1684526330384_0004 completed successfully\n', '2023-05-19 20:06:47,771 INFO mapreduce.Job: Counters: 55\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=3338507\n', '\t\tFILE: Number of bytes written=8430502\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=599219601\n', '\t\tHDFS: Number of bytes written=7402170\n', '\t\tHDFS: Number of read operations=23\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tKilled map tasks=2\n', '\t\tLaunched map tasks=8\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=8\n', '\t\tTotal time spent by all maps in occupied slots (ms)=526344\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=135664\n', '\t\tTotal time spent by all map tasks (ms)=131586\n', '\t\tTotal time spent by all reduce tasks (ms)=16958\n', '\t\tTotal vcore-milliseconds taken by all map tasks=131586\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=16958\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=538976256\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=1389199 ...

# %%
print_hdfs_output(steam_01_output_path)
# Out:
# ['10\t{"game_id":10,"name":"Counter-Strike","positive":196557,"negative":5070,"owners":"10,000,000 .. 20,000,000","ccu":12877,"release_date":"2000-11-01"}\n', '1000000\t{"game_id":1000000,"name":"ASCENXION","positive":27,"negative":5,"owners":"0 .. 20,000","ccu":0,"release_date":"2021-05-14"}\n', '1000010\t{"game_id":1000010,"name":"Crown Trick","positive":3809,"negative":583,"owners":"200,000 .. 500,000","ccu":51,"release_date":"2020-10-16"}\n', '1000030\t{"game_id":1000030,"name":"Cook, Serve, Delicious! 3?!","positive":1469,"negative":101,"owners":"50,000 .. 100,000","ccu":54,"release_date":"2020-10-14"}\n', '1000040\t{"game_id":1000040,"name":"细胞战争","positive":0,"negative":1,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-03-30"}\n', '1000080\t{"game_id":1000080,"name":"Zengeon","positive":1011,"negative":431,"owners":"50,000 .. 100,000","ccu":2,"release_date":"2019-06-24"}\n', '1000100\t{"game_id":1000100,"name":"干支セトラ\u3000陽ノ卷｜干支etc.\u3000陽之卷","positive":18,"negative":6,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-01-24"}\n', '1000110\t{"game_id":1000110,"name":"Jumping Master(跳跳大咖)","positive":51,"negative":34,"owners":"20,000 .. 50,000","ccu":0,"release_date":"2019-04-08"}\n', '1000130\t{"game_id":1000130,"name":"Cube Defender","positive":6,"negative":0,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-01-06"}\n', '1000280\t{"game_id":1000280,"name":"Tower of Origin2-Worm\'s Nest","positive":31,"negative":11,"owners":"0 .. 20,000","ccu":0,"release_date":"2021-09-09"}\n', '1000310\t{"game_id":1000310,"name":"人气动漫大乱斗","positive":1,"negative":5,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-12-17"}\n', '1000360\t{"game_id":1000360,"name":"Hellish Quart","positive":3628,"negative":256,"owners":"100,000 .. 200,000","ccu":46,"release_date":"2021-02-16"}\n', '1000370\t{"game_id":1000370,"name":"SurReal Subway","positive":0,"negative":1,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-01-03"}\n', '1000380\t{"game_id":1000380,"name":"Rogue Reaper","positive":306,"negative":86,"owners":"100,000 .. 200,000","ccu":0,"release_date":"2019-02-01"}\n', '1000410\t{"game_id":1000410,"name":"WRATH: Aeon of Ruin","positive":1168,"negative":271,"owners":"20,000 .. 50,000","ccu":2,"release_date":"2019-11-22"}\n', '1000470\t{"game_id":1000470,"name":"Drawngeon: Dungeons of Ink and Paper","positive":55,"negative":13,"owners":"20,000 .. 50,000","ccu":0,"release_date":"2019-05-24"}\n', '1000480\t{"game_id":1000480,"name":"Battle Motion","positive":9,"negative":6,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-02-04"}\n', '1000500\t{"game_id":1000500,"name":"Elden Gunfire : The Undisputables","positive":7,"negative":3,"owners":"100,000 .. 200,000","ccu":0,"release_date":"2021-12-05"}\n', '1000510\t{"game_id":1000510,"name":"The Marvellous Machine","positive":92,"negative":18,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-02-11"}\n', '1000540\t{"game_id":1000540,"name":"Tactical Control","positive":53,"negative":12,"owners":"20,000 .. 50,000","ccu":0,"release_date":"2019-03-21"}\n', '1000550\t{"game_id":1000550,"name":"Love Hentai: Endgame","positive":0,"negative":0,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-02-20"}\n', '1000600\t{"game_id":1000600,"name":"The ScreaMaze","positive":6,"negative":1,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-01-10"}\n', '1000650\t{"game_id":1000650,"name":"Fist Of Heaven & Hell","positive":7,"negative":0,"owners":"0 .. 20,000","ccu":0,"release_date":"2019-06-28"}\n', '1000750\t{"game_id":1000750,"name":"Rotund Rebound","positive":5,"negative":0,"owners":"0 .. 20,000","ccu":0,"release_date":"2022-04-01"}\n', '1000760\t{"game_id":1000760,"name":"Foregone","positive":524,"negative":106,"owners":"20,000 .. 50,000","ccu":2,"release_date":"2021-03-01"}\n', '1000770\t{"game_id":1000770,"name":"Urban Tale","positive":89,"negative":31,"owners":"0 .. 20,000","ccu":0,"release_date":"2021-10-07"}\n', '1000790\t{"game_id":1000790,"name":"Flex Apocalypse Racing","positive":5,"negati ...

# %% [markdown]
# ## Selekcja gier

# %%
steam_02_jar_path = "/data/master_volume/map_reduce_jars/steam_02_choose.jar"
steam_02_input_path = get_data_from_output_path(steam_01_output_path)
steam_02_output_path = "/out_steam_2" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {steam_02_jar_path} {steam_02_input_path} {steam_02_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:07:25,670 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:07:25,729 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:07:25,808 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:07:25,837 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0006\n', '2023-05-19 20:07:26,003 INFO input.FileInputFormat: Total input files to process : 1\n', '2023-05-19 20:07:26,075 INFO mapreduce.JobSubmitter: number of splits:1\n', '2023-05-19 20:07:26,577 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0006\n', '2023-05-19 20:07:26,577 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:07:26,670 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:07:26,670 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:07:27,300 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0006\n', '2023-05-19 20:07:27,324 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0006/\n', '2023-05-19 20:07:27,324 INFO mapreduce.Job: Running job: job_1684526330384_0006\n', '2023-05-19 20:07:32,369 INFO mapreduce.Job: Job job_1684526330384_0006 running in uber mode : false\n', '2023-05-19 20:07:32,370 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:07:36,401 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-19 20:07:40,414 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:07:40,419 INFO mapreduce.Job: Job job_1684526330384_0006 completed successfully\n', '2023-05-19 20:07:40,476 INFO mapreduce.Job: Counters: 54\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=1334\n', '\t\tFILE: Number of bytes written=554529\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=7402316\n', '\t\tHDFS: Number of bytes written=4327\n', '\t\tHDFS: Number of read operations=8\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tLaunched map tasks=1\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=1\n', '\t\tTotal time spent by all maps in occupied slots (ms)=7756\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=8544\n', '\t\tTotal time spent by all map tasks (ms)=1939\n', '\t\tTotal time spent by all reduce tasks (ms)=1068\n', '\t\tTotal vcore-milliseconds taken by all map tasks=1939\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=1068\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=7942144\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=8749056\n', '\tMap-Reduce Framework\n', '\t\tMap input records=51492\n', '\t\tMap output records=27\n', '\t\tMap output bytes=4354\n', '\t\tMap output materialized bytes=1326\n', '\t\tInput split bytes=146\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=27\n', '\t\tReduce shuffle bytes=1326\n', '\t\tReduce input records=27\n', '\t\tReduce output records=27\n', '\t\tSpilled Records=54\n', '\t\tShuffled Maps =1\n', '\t\tFailed Shuffles=0\n', '\t\tMerged Map outputs=1\n', '\t\tGC time elapsed (ms)=102\n', '\t\tCPU time spent (ms)=2390\n', '\t\tPhysical memory (bytes) snapshot=762986496\n', '\t\tVirtual memory (bytes) snapshot=13444321280\n', '\t\tTotal committed heap usage (bytes)=969932800\n', '\t\tPeak Map Physical memory (bytes)=485355520\n', '\t\tPeak Map Virtual memory (bytes)=5059399680\n', '\t\tPeak Reduce Phys ...

# %%
print_hdfs_output(steam_02_output_path)
# Out:
# ['10\t{"game_id":10,"name":"Counter-Strike","positive":196557,"negative":5070,"owners":"10,000,000 .. 20,000,000","ccu":12877,"release_date":"2000-11-01"}\n', '105600\t{"game_id":105600,"name":"Terraria","positive":941388,"negative":20346,"owners":"20,000,000 .. 50,000,000","ccu":39371,"release_date":"2011-05-16"}\n', '1085660\t{"game_id":1085660,"name":"Destiny 2","positive":396069,"negative":74899,"owners":"20,000,000 .. 50,000,000","ccu":106858,"release_date":"2019-10-01"}\n', '218620\t{"game_id":218620,"name":"PAYDAY 2","positive":513225,"negative":62272,"owners":"20,000,000 .. 50,000,000","ccu":39437,"release_date":"2013-08-13"}\n', '227300\t{"game_id":227300,"name":"Euro Truck Simulator 2","positive":535815,"negative":14706,"owners":"10,000,000 .. 20,000,000","ccu":33648,"release_date":"2012-10-12"}\n', '230410\t{"game_id":230410,"name":"Warframe","positive":437656,"negative":47546,"owners":"20,000,000 .. 50,000,000","ccu":50453,"release_date":"2013-03-25"}\n', '240\t{"game_id":240,"name":"Counter-Strike: Source","positive":133140,"negative":5282,"owners":"10,000,000 .. 20,000,000","ccu":6742,"release_date":"2004-11-01"}\n', '242760\t{"game_id":242760,"name":"The Forest","positive":352728,"negative":17875,"owners":"10,000,000 .. 20,000,000","ccu":10867,"release_date":"2018-04-30"}\n', '252950\t{"game_id":252950,"name":"Rocket League","positive":491121,"negative":61954,"owners":"10,000,000 .. 20,000,000","ccu":33620,"release_date":"2015-07-06"}\n', '271590\t{"game_id":271590,"name":"Grand Theft Auto V","positive":1144201,"negative":208030,"owners":"20,000,000 .. 50,000,000","ccu":109264,"release_date":"2015-04-13"}\n', '291550\t{"game_id":291550,"name":"Brawlhalla","positive":241131,"negative":45296,"owners":"20,000,000 .. 50,000,000","ccu":18853,"release_date":"2017-10-17"}\n', '292030\t{"game_id":292030,"name":"The Witcher 3: Wild Hunt","positive":610130,"negative":24802,"owners":"10,000,000 .. 20,000,000","ccu":18042,"release_date":"2015-05-18"}\n', '304930\t{"game_id":304930,"name":"Unturned","positive":438411,"negative":40925,"owners":"20,000,000 .. 50,000,000","ccu":50423,"release_date":"2017-07-07"}\n', '322330\t{"game_id":322330,"name":"Don\'t Starve Together","positive":321194,"negative":12820,"owners":"10,000,000 .. 20,000,000","ccu":31708,"release_date":"2016-04-21"}\n', '346110\t{"game_id":346110,"name":"ARK: Survival Evolved","positive":430401,"negative":94499,"owners":"10,000,000 .. 20,000,000","ccu":63040,"release_date":"2017-08-27"}\n', '381210\t{"game_id":381210,"name":"Dead by Daylight","positive":484780,"negative":110274,"owners":"10,000,000 .. 20,000,000","ccu":44247,"release_date":"2016-06-14"}\n', '386360\t{"game_id":386360,"name":"SMITE","positive":79849,"negative":19831,"owners":"10,000,000 .. 20,000,000","ccu":18597,"release_date":"2015-09-08"}\n', '440\t{"game_id":440,"name":"Team Fortress 2","positive":813122,"negative":56073,"owners":"50,000,000 .. 100,000,000","ccu":82571,"release_date":"2007-10-10"}\n', '444090\t{"game_id":444090,"name":"Paladins","positive":278913,"negative":46919,"owners":"10,000,000 .. 20,000,000","ccu":9888,"release_date":"2018-05-08"}\n', '444200\t{"game_id":444200,"name":"World of Tanks Blitz","positive":89929,"negative":21787,"owners":"10,000,000 .. 20,000,000","ccu":24669,"release_date":"2016-11-09"}\n', '49520\t{"game_id":49520,"name":"Borderlands 2","positive":246030,"negative":16541,"owners":"10,000,000 .. 20,000,000","ccu":5454,"release_date":"2012-09-17"}\n', '550\t{"game_id":550,"name":"Left 4 Dead 2","positive":600580,"negative":15752,"owners":"20,000,000 .. 50,000,000","ccu":20819,"release_date":"2009-11-16"}\n', '552990\t{"game_id":552990,"name":"World of Warships","positive":82153,"negative":19765,"owners":"10,000,000 .. 20,000,000","ccu":12539,"release_date":"2017-11-15"}\n', '570\t{"game_id":570,"name":"Dota 2","positive":1456697,"negative":291673,"owners":"100,000,000 .. 200,000,000","ccu":612293,"release_date":"2013-07-09"}\n', '582010\t{"game_id":582010 ...

# %% [markdown]
# ## Wybór pierwszych N gier

# %%
steam_03_jar_path = "/data/master_volume/map_reduce_jars/steam_03_takeN.jar"
steam_03_input_path = get_data_from_output_path(steam_02_output_path)
steam_03_output_path = "/out_steam_3" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {steam_03_jar_path} {steam_03_input_path} {steam_03_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:07:43,732 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:07:43,789 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:07:43,869 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:07:43,893 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0007\n', '2023-05-19 20:07:44,048 INFO input.FileInputFormat: Total input files to process : 1\n', '2023-05-19 20:07:44,518 INFO mapreduce.JobSubmitter: number of splits:1\n', '2023-05-19 20:07:44,603 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0007\n', '2023-05-19 20:07:44,603 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:07:44,675 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:07:44,675 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:07:45,306 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0007\n', '2023-05-19 20:07:45,329 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0007/\n', '2023-05-19 20:07:45,329 INFO mapreduce.Job: Running job: job_1684526330384_0007\n', '2023-05-19 20:07:50,364 INFO mapreduce.Job: Job job_1684526330384_0007 running in uber mode : false\n', '2023-05-19 20:07:50,365 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:07:54,397 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-19 20:07:57,406 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:07:57,411 INFO mapreduce.Job: Job job_1684526330384_0007 completed successfully\n', '2023-05-19 20:07:57,462 INFO mapreduce.Job: Counters: 54\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=558\n', '\t\tFILE: Number of bytes written=552931\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=4473\n', '\t\tHDFS: Number of bytes written=926\n', '\t\tHDFS: Number of read operations=8\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tLaunched map tasks=1\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=1\n', '\t\tTotal time spent by all maps in occupied slots (ms)=7176\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=8352\n', '\t\tTotal time spent by all map tasks (ms)=1794\n', '\t\tTotal time spent by all reduce tasks (ms)=1044\n', '\t\tTotal vcore-milliseconds taken by all map tasks=1794\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=1044\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=7348224\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=8552448\n', '\tMap-Reduce Framework\n', '\t\tMap input records=27\n', '\t\tMap output records=27\n', '\t\tMap output bytes=1235\n', '\t\tMap output materialized bytes=550\n', '\t\tInput split bytes=146\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=1\n', '\t\tReduce shuffle bytes=550\n', '\t\tReduce input records=27\n', '\t\tReduce output records=20\n', '\t\tSpilled Records=54\n', '\t\tShuffled Maps =1\n', '\t\tFailed Shuffles=0\n', '\t\tMerged Map outputs=1\n', '\t\tGC time elapsed (ms)=90\n', '\t\tCPU time spent (ms)=1340\n', '\t\tPhysical memory (bytes) snapshot=697675776\n', '\t\tVirtual memory (bytes) snapshot=13443899392\n', '\t\tTotal committed heap usage (bytes)=956825600\n', '\t\tPeak Map Physical memory (bytes)=420331520\n', '\t\tPeak Map Virtual memory (bytes)=5058502656\n', '\t\tPeak Reduce Physical memory  ...

# %%
print_hdfs_output(steam_03_output_path)
# Out:
# ['id\t{"game_id":945360,"name":"Among Us"}\n', 'id\t{"game_id":730,"name":"Counter-Strike: Global Offensive"}\n', 'id\t{"game_id":582010,"name":"Monster Hunter: World"}\n', 'id\t{"game_id":570,"name":"Dota 2"}\n', 'id\t{"game_id":552990,"name":"World of Warships"}\n', 'id\t{"game_id":550,"name":"Left 4 Dead 2"}\n', 'id\t{"game_id":49520,"name":"Borderlands 2"}\n', 'id\t{"game_id":444200,"name":"World of Tanks Blitz"}\n', 'id\t{"game_id":444090,"name":"Paladins"}\n', 'id\t{"game_id":440,"name":"Team Fortress 2"}\n', 'id\t{"game_id":386360,"name":"SMITE"}\n', 'id\t{"game_id":381210,"name":"Dead by Daylight"}\n', 'id\t{"game_id":346110,"name":"ARK: Survival Evolved"}\n', 'id\t{"game_id":322330,"name":"Don\'t Starve Together"}\n', 'id\t{"game_id":304930,"name":"Unturned"}\n', 'id\t{"game_id":292030,"name":"The Witcher 3: Wild Hunt"}\n', 'id\t{"game_id":291550,"name":"Brawlhalla"}\n', 'id\t{"game_id":271590,"name":"Grand Theft Auto V"}\n', 'id\t{"game_id":252950,"name":"Rocket League"}\n', 'id\t{"game_id":242760,"name":"The Forest"}\n']

# %% [markdown]
# ## Pobranie danych ze Steam Charts API

# %%
steam_04_jar_path = "/data/master_volume/map_reduce_jars/steam_04_fetch.jar"
steam_04_input_path = get_data_from_output_path(steam_03_output_path)
steam_04_output_path = "/out_steam_4" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {steam_04_jar_path} {steam_04_input_path} {steam_04_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:08:00,705 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:08:00,763 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:08:00,840 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:08:00,858 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0008\n', '2023-05-19 20:08:00,991 INFO input.FileInputFormat: Total input files to process : 1\n', '2023-05-19 20:08:01,028 INFO mapreduce.JobSubmitter: number of splits:1\n', '2023-05-19 20:08:01,094 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0008\n', '2023-05-19 20:08:01,094 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:08:01,179 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:08:01,179 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:08:01,814 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0008\n', '2023-05-19 20:08:01,830 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0008/\n', '2023-05-19 20:08:01,831 INFO mapreduce.Job: Running job: job_1684526330384_0008\n', '2023-05-19 20:08:05,865 INFO mapreduce.Job: Job job_1684526330384_0008 running in uber mode : false\n', '2023-05-19 20:08:05,866 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:08:21,918 INFO mapreduce.Job:  map 17% reduce 0%\n', '2023-05-19 20:08:27,934 INFO mapreduce.Job:  map 27% reduce 0%\n', '2023-05-19 20:08:32,953 INFO mapreduce.Job:  map 33% reduce 0%\n', '2023-05-19 20:08:38,967 INFO mapreduce.Job:  map 43% reduce 0%\n', '2023-05-19 20:08:44,980 INFO mapreduce.Job:  map 54% reduce 0%\n', '2023-05-19 20:08:50,995 INFO mapreduce.Job:  map 60% reduce 0%\n', '2023-05-19 20:08:57,015 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-19 20:09:00,021 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:09:01,027 INFO mapreduce.Job: Job job_1684526330384_0008 completed successfully\n', '2023-05-19 20:09:01,082 INFO mapreduce.Job: Counters: 54\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=143085\n', '\t\tFILE: Number of bytes written=837563\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=1072\n', '\t\tHDFS: Number of bytes written=734257\n', '\t\tHDFS: Number of read operations=8\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tLaunched map tasks=1\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=1\n', '\t\tTotal time spent by all maps in occupied slots (ms)=194344\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=8784\n', '\t\tTotal time spent by all map tasks (ms)=48586\n', '\t\tTotal time spent by all reduce tasks (ms)=1098\n', '\t\tTotal vcore-milliseconds taken by all map tasks=48586\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=1098\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=199008256\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=8994816\n', '\tMap-Reduce Framework\n', '\t\tMap input records=20\n', '\t\tMap output records=20\n', '\t\tMap output bytes=734297\n', '\t\tMap output materialized bytes=143077\n', '\t\tInput split bytes=146\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=20\n', '\t\tReduce shuffle bytes=143077\n', '\t\tReduce input records=20\n', '\t\tReduce output records=20\n', '\t\tSpilled Records=40\n', '\t\tShuffled Map ...

# %%
print_hdfs_output(steam_04_output_path)
# Out:
# ['242760\t{"game_id":242760,"playcounts":[{"timestamp":1398902400000,"count":5722},{"timestamp":1401580800000,"count":6673},{"timestamp":1404172800000,"count":4725},{"timestamp":1406851200000,"count":3121},{"timestamp":1409529600000,"count":1875},{"timestamp":1412121600000,"count":2918},{"timestamp":1414800000000,"count":4640},{"timestamp":1417392000000,"count":3891},{"timestamp":1420070400000,"count":4809},{"timestamp":1422748800000,"count":3215},{"timestamp":1425168000000,"count":3194},{"timestamp":1427846400000,"count":2241},{"timestamp":1430438400000,"count":1990},{"timestamp":1433116800000,"count":4689},{"timestamp":1435708800000,"count":3421},{"timestamp":1438387200000,"count":4060},{"timestamp":1441065600000,"count":3686},{"timestamp":1443657600000,"count":3240},{"timestamp":1446336000000,"count":3788},{"timestamp":1448928000000,"count":4962},{"timestamp":1451606400000,"count":6245},{"timestamp":1454284800000,"count":6306},{"timestamp":1456790400000,"count":4793},{"timestamp":1459468800000,"count":4767},{"timestamp":1462060800000,"count":5120},{"timestamp":1464739200000,"count":7430},{"timestamp":1467331200000,"count":7888},{"timestamp":1470009600000,"count":4932},{"timestamp":1472688000000,"count":5077},{"timestamp":1475280000000,"count":4826},{"timestamp":1477958400000,"count":6941},{"timestamp":1480550400000,"count":16972},{"timestamp":1483228800000,"count":18273},{"timestamp":1485907200000,"count":11106},{"timestamp":1488326400000,"count":7030},{"timestamp":1491004800000,"count":5468},{"timestamp":1493596800000,"count":5707},{"timestamp":1496275200000,"count":7873},{"timestamp":1498867200000,"count":7707},{"timestamp":1501545600000,"count":5978},{"timestamp":1504224000000,"count":6115},{"timestamp":1506816000000,"count":8243},{"timestamp":1509494400000,"count":8865},{"timestamp":1512086400000,"count":12249},{"timestamp":1514764800000,"count":11300},{"timestamp":1517443200000,"count":11253},{"timestamp":1519862400000,"count":7626},{"timestamp":1522540800000,"count":15745},{"timestamp":1525132800000,"count":25577},{"timestamp":1527811200000,"count":21553},{"timestamp":1530403200000,"count":17613},{"timestamp":1533081600000,"count":7873},{"timestamp":1535760000000,"count":7588},{"timestamp":1538352000000,"count":10482},{"timestamp":1541030400000,"count":13137},{"timestamp":1543622400000,"count":20925},{"timestamp":1546300800000,"count":18954},{"timestamp":1548979200000,"count":17363},{"timestamp":1551398400000,"count":8634},{"timestamp":1554076800000,"count":7637},{"timestamp":1556668800000,"count":7482},{"timestamp":1559347200000,"count":11432},{"timestamp":1561939200000,"count":12098},{"timestamp":1564617600000,"count":6834},{"timestamp":1567296000000,"count":17275},{"timestamp":1569888000000,"count":8309},{"timestamp":1572566400000,"count":10848},{"timestamp":1575158400000,"count":15029},{"timestamp":1577836800000,"count":19189},{"timestamp":1580515200000,"count":15596},{"timestamp":1583020800000,"count":27977},{"timestamp":1585699200000,"count":16351},{"timestamp":1588291200000,"count":11583},{"timestamp":1590969600000,"count":16215},{"timestamp":1593561600000,"count":16117},{"timestamp":1596240000000,"count":7906},{"timestamp":1598918400000,"count":7633},{"timestamp":1601510400000,"count":20294},{"timestamp":1604188800000,"count":25440},{"timestamp":1606780800000,"count":29909},{"timestamp":1609459200000,"count":32817},{"timestamp":1612137600000,"count":31612},{"timestamp":1614556800000,"count":11806},{"timestamp":1617235200000,"count":63683},{"timestamp":1619827200000,"count":25808},{"timestamp":1622505600000,"count":25557},{"timestamp":1625097600000,"count":27317},{"timestamp":1627776000000,"count":9593},{"timestamp":1630454400000,"count":8708},{"timestamp":1633046400000,"count":36688},{"timestamp":1635724800000,"count":39049},{"timestamp":1638316800000,"count":26467},{"timestamp":1640995200000,"count":34172},{"timestamp":1643673600000,"count":33109},{"timestamp":1646092800000,"count":10529},{"timestamp":1648771 ...

# %% [markdown]
# ## Złączenie z wymiarem czasu

# %%
steam_05_jar_path = "/data/master_volume/map_reduce_jars/steam_05_merge_time.jar"
steam_05_input_path = get_data_from_output_path(steam_04_output_path)
steam_05_input_path2 = get_data_from_output_path(covid_02_output_path)
steam_05_output_path = "/out_steam_5" + str(uuid.uuid4())

res = run_in_master(f"yarn jar {steam_05_jar_path} {steam_05_input_path} {steam_05_input_path2} {steam_05_output_path}")
print(res)
# Out:
# ([], ['2023-05-19 20:09:04,390 INFO client.DefaultNoHARMFailoverProxyProvider: Connecting to ResourceManager at resourcemanager/172.30.0.2:8032\n', '2023-05-19 20:09:04,450 INFO client.AHSProxy: Connecting to Application History server at historyserver/172.30.0.8:10200\n', '2023-05-19 20:09:04,539 WARN mapreduce.JobResourceUploader: Hadoop command-line option parsing not performed. Implement the Tool interface and execute your application with ToolRunner to remedy this.\n', '2023-05-19 20:09:04,558 INFO mapreduce.JobResourceUploader: Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1684526330384_0009\n', '2023-05-19 20:09:04,721 INFO input.FileInputFormat: Total input files to process : 2\n', '2023-05-19 20:09:05,593 INFO mapreduce.JobSubmitter: number of splits:2\n', '2023-05-19 20:09:06,087 INFO mapreduce.JobSubmitter: Submitting tokens for job: job_1684526330384_0009\n', '2023-05-19 20:09:06,087 INFO mapreduce.JobSubmitter: Executing with tokens: []\n', '2023-05-19 20:09:06,172 INFO conf.Configuration: resource-types.xml not found\n', "2023-05-19 20:09:06,172 INFO resource.ResourceUtils: Unable to find 'resource-types.xml'.\n", '2023-05-19 20:09:06,804 INFO impl.YarnClientImpl: Submitted application application_1684526330384_0009\n', '2023-05-19 20:09:06,825 INFO mapreduce.Job: The url to track the job: http://resourcemanager:8088/proxy/application_1684526330384_0009/\n', '2023-05-19 20:09:06,826 INFO mapreduce.Job: Running job: job_1684526330384_0009\n', '2023-05-19 20:09:10,863 INFO mapreduce.Job: Job job_1684526330384_0009 running in uber mode : false\n', '2023-05-19 20:09:10,864 INFO mapreduce.Job:  map 0% reduce 0%\n', '2023-05-19 20:09:16,928 INFO mapreduce.Job:  map 100% reduce 0%\n', '2023-05-19 20:09:20,939 INFO mapreduce.Job:  map 100% reduce 100%\n', '2023-05-19 20:09:21,946 INFO mapreduce.Job: Job job_1684526330384_0009 completed successfully\n', '2023-05-19 20:09:22,000 INFO mapreduce.Job: Counters: 54\n', '\tFile System Counters\n', '\t\tFILE: Number of bytes read=282310\n', '\t\tFILE: Number of bytes written=1386691\n', '\t\tFILE: Number of read operations=0\n', '\t\tFILE: Number of large read operations=0\n', '\t\tFILE: Number of write operations=0\n', '\t\tHDFS: Number of bytes read=8344399\n', '\t\tHDFS: Number of bytes written=105074\n', '\t\tHDFS: Number of read operations=11\n', '\t\tHDFS: Number of large read operations=0\n', '\t\tHDFS: Number of write operations=2\n', '\t\tHDFS: Number of bytes read erasure-coded=0\n', '\tJob Counters \n', '\t\tLaunched map tasks=2\n', '\t\tLaunched reduce tasks=1\n', '\t\tRack-local map tasks=2\n', '\t\tTotal time spent by all maps in occupied slots (ms)=18124\n', '\t\tTotal time spent by all reduces in occupied slots (ms)=12704\n', '\t\tTotal time spent by all map tasks (ms)=4531\n', '\t\tTotal time spent by all reduce tasks (ms)=1588\n', '\t\tTotal vcore-milliseconds taken by all map tasks=4531\n', '\t\tTotal vcore-milliseconds taken by all reduce tasks=1588\n', '\t\tTotal megabyte-milliseconds taken by all map tasks=18558976\n', '\t\tTotal megabyte-milliseconds taken by all reduce tasks=13008896\n', '\tMap-Reduce Framework\n', '\t\tMap input records=304414\n', '\t\tMap output records=364686\n', '\t\tMap output bytes=9299472\n', '\t\tMap output materialized bytes=276382\n', '\t\tInput split bytes=292\n', '\t\tCombine input records=0\n', '\t\tCombine output records=0\n', '\t\tReduce input groups=3975\n', '\t\tReduce shuffle bytes=276382\n', '\t\tReduce input records=364686\n', '\t\tReduce output records=1208\n', '\t\tSpilled Records=729372\n', '\t\tShuffled Maps =2\n', '\t\tFailed Shuffles=0\n', '\t\tMerged Map outputs=2\n', '\t\tGC time elapsed (ms)=190\n', '\t\tCPU time spent (ms)=7330\n', '\t\tPhysical memory (bytes) snapshot=1391157248\n', '\t\tVirtual memory (bytes) snapshot=18501050368\n', '\t\tTotal committed heap usage (bytes)=1822949376\n', '\t\tPeak Map Physical memory (bytes)=582361088\n', '\t\tPeak Map Virtual memory (bytes)= ...

# %%
print_hdfs_output(steam_05_output_path)
# Out:
# ['id\t{"date":"2020-01-01","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-02","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-03","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-04","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-05","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-06","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-07","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-08","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-09","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-10","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-11","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-12","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-13","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-14","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-15","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-16","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-17","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-18","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-19","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-20","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-21","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-22","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-23","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-24","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-25","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-26","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-27","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-28","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-29","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-30","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-01-31","mostPopular":730,"averageGamersCount":126531,"total":2530628}\n', 'id\t{"date":"2020-02-01","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-02","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-03","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-04","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-05","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-06","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-07","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-08","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-09","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-10","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-11","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n', 'id\t{"date":"2020-02-12","mostPopular":730,"averageGamersCount":134430,"total":2688602}\n',  ...

# %% [markdown]
# ## Fragmenty kodu

# %% [markdown]
# ## Selekcja gier

# %% [markdown]
# ```scala
#   class MyMapper extends HadoopJob.HadoopMapper[AnyRef, Text, Text, Text] {
#     override def myMap(key: AnyRef, value: Text, emit: (Text, Text) => Unit): Unit = {
#       value.toString
#         .split("\n")
#         .map(x => x.dropWhile(!_.isWhitespace))
#         .toList
#         .flatMap(x => SteamJoined.decoder.decodeJson(x).toOption)
#         .filter(game => before2020(game.release_date))
#         .filter(game => overwhelminglyPositive(game))
#         .filter(game => game.ccu > 5000)
#         .filter(game => has_many_owners(game))
#         .foreach(x => emit(Text(x.game_id.toString), Text(x.toJson)))
#     }
#
#     private def overwhelminglyPositive(steamJoined: SteamJoined): Boolean =
#       steamJoined.positive > 30000 &&
#         (steamJoined.positive.toDouble / (steamJoined.positive + steamJoined.negative)) > 0.8
#
#     private def before2020(date: String): Boolean = {
#       Try(isoFormat.parse(date)) match
#         case Failure(_)     => false
#         case Success(value) => value.get(java.time.temporal.ChronoField.YEAR) < 2020
#     }
#
#     private def has_many_owners(steamJoined: SteamJoined): Boolean =
#       Try(steamJoined.owners.replace(",", "").split('.').head.trim.toInt) match
#         case Failure(_)     => false
#         case Success(value) => value > 5000000
#   }
#
#   class MyReducer extends HadoopJob.HadoopReducer[Text, Text, Text] {
#     override def myReduce(key: Text, values: List[String], emit: (Text, Text) => Unit): Unit = {
#       values.foreach(x => emit(key, Text(x)))
#     }
#   }
# ```

# %% [markdown]
# ## Wybór pierwszych N gier

# %% [markdown]
# ```scala
#   class MyMapper extends HadoopJob.HadoopMapper[AnyRef, Text, Text, Text] {
#     override def myMap(key: AnyRef, value: Text, emit: (Text, Text) => Unit): Unit = {
#       val jsons  = value.toString.split("\n").map(x => x.dropWhile(!_.isWhitespace)).toList
#       val mapped = jsons.flatMap(x => SteamJoined.decoder.decodeJson(x).toOption)
#       val result = mapped.map(x => Result(x.game_id, x.name))
#
#       result.foreach(x => emit(Text("id"), Text(x.toJson)))
#     }
#   }
#
#   class MyReducer extends HadoopJob.HadoopReducer[Text, Text, Text] {
#     override def myReduce(key: Text, values: List[String], emit: (Text, Text) => Unit): Unit = {
#       values.take(20).foreach(x => emit(key, Text(x)))
#     }
#   }
# ```

# %% [markdown]
# ## Pobranie danych ze Steam Charts API

# %% [markdown]
# ```scala
#   class MyMapper extends HadoopJob.HadoopMapper[AnyRef, Text, Text, Text] {
#     override def myMap(key: AnyRef, value: Text, emit: (Text, Text) => Unit): Unit = {
#       val jsons  = value.toString.split("\n").map(x => x.dropWhile(!_.isWhitespace)).map(_.trim).toList
#       val mapped = jsons.flatMap(x => Input.decoder.decodeJson(x).toOption)
#
#       def downloadTimestamps(id: Int) = for {
#         res  <- zio.http.Client.request(f"""https://steamcharts.com/app/$id/chart-data.json""")
#         data <- res.body.asString
#         json  = data.fromJson[ApiResult].getOrElse(List.empty)
#       } yield json
#
#       val workflow = ZIO.foreach(mapped)(x => downloadTimestamps(x.game_id).map(res => (x, res)))
#
#       val result = runZIO(
#         workflow
#           .tapError(err => { ZIO.succeed(emit(Text("error!"), Text(err.getMessage))) })
#           .orElse(ZIO.succeed(List.empty))
#           .provide(zio.http.Client.default)
#       ).map(x => Result(x._1.game_id, x._2.map(y => PlayCount(y.head, y.last))))
#
#       result.foreach { x =>
#         emit(new Text(x.game_id.toString), Text(x.toJson))
#       }
#     }
#   }
#
#   class MyReducer extends HadoopJob.HadoopReducer[Text, Text, Text] {
#     override def myReduce(key: Text, values: List[String], emit: (Text, Text) => Unit): Unit = {
#       values.foreach(x => emit(key, Text(x)))
#     }
#   }
# ```

# %% [markdown]
# ## Wybór kolumn

# %% [markdown]
# ```scala
#   class MyMapper extends HadoopJob.HadoopMapper[AnyRef, Text, Text, Text] {
#     override def myMap(key: AnyRef, value: Text, emit: (Text, Text) => Unit): Unit = {
#       val rawInput    = value.toString.fromJson[Input].toOption.get
#       val parsedInput = InputParsed(
#         date = LocalDate.parse(rawInput.date),
#         country = rawInput.location,
#         total_cases = rawInput.total_cases.toFloatOption.getOrElse(0),
#         new_cases = rawInput.new_cases.toFloatOption.getOrElse(0),
#         total_deaths = rawInput.total_cases.toFloatOption.getOrElse(0),
#         new_deaths = rawInput.new_deaths.toFloatOption.getOrElse(0),
#         new_cases_per_million = rawInput.new_cases_per_million.toFloatOption.getOrElse(0.0f)
#       )
#       emit(Text("id"), Text(parsedInput.toJson))
#     }
#   }
#
#   class MyReducer extends HadoopJob.HadoopReducer[Text, Text, Text] {
#     override def myReduce(key: Text, values: List[String], emit: (Text, Text) => Unit): Unit = {
#
#       logRemoteInfo("http://195.22.98.134:2138", "ReducerStarted")
#
#       val inputs = values.flatMap(_.fromJson[InputParsed].toOption)
#
#       logRemoteInfo("http://195.22.98.134:2138", "ReducerParsedInput")
#
#       val average =  inputs.map(y => y.new_cases_per_million).sum / inputs.length
#
#       logRemoteInfo("http://195.22.98.134:2138", "AverageCalculated");
#
#       inputs
#         .map(x =>
#           Output(
#             x.date,
#             x.country,
#             x.total_cases.toInt,
#             x.new_cases.toInt,
#             x.total_deaths.toInt,
#             x.new_deaths.toInt,
#             average
#           )
#         )
#         .foreach(x => emit(key, Text(x.toJson)))
#     }
#   }
# ```
