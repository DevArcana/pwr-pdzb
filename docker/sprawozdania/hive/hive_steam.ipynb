# %%
import docker
import uuid
import paramiko
import os
from timeit import default_timer as timer
from dataclasses import dataclass
import re
import requests
import statistics
import pandas as pd
import numpy as np

# %%
def run_in_master(command):
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect("namenode", username="root", password="pass")
    ssh_stdin, ssh_stdout, ssh_stderr = ssh.exec_command(f"cd /app/ && . /env_var_path.sh && {command}")
    return (ssh_stdout.readlines(), ssh_stderr.readlines())

def run_in_hive(command):
    ssh = paramiko.SSHClient()
    ssh.set_missing_host_key_policy(paramiko.AutoAddPolicy())
    ssh.connect("hive-server", username="root", password="pass")
    ssh_stdin, ssh_stdout, ssh_stderr = ssh.exec_command(f"bash -c '. /env_var_path.sh && {command}'")
    return (ssh_stdout.readlines(), ssh_stderr.readlines())

# %%
run_in_hive("hive -f /data/master_volume/hive_scripts/steam_01_combine.hql")
# Out:
# (['570\tDota 2\tValve\tValve\t\t1456697\t291673\t0\t100,000,000 .. 200,000,000\t39576\t1788\t1021\t944\t0\t0\t0\t612293\n',
#   '730\tCounter-Strike: Global Offensive\tValve, Hidden Path Entertainment\tValve\t\t5680980\t756795\t0\t50,000,000 .. 100,000,000\t29878\t858\t6437\t300\t0\t0\t0\t679488\n',
#   '578080\tPUBG: BATTLEGROUNDS\tKRAFTON, Inc.\tKRAFTON, Inc.\t\t1139437\t888720\t0\t50,000,000 .. 100,000,000\t21370\t964\t6632\t176\t0\t0\t0\t279181\n',
#   '1063730\tNew World\tAmazon Games\tAmazon Games\t\t153807\t73148\t0\t50,000,000 .. 100,000,000\t8392\t590\t3408\t490\t3999\t3999\t0\t20403\n',
#   '440\tTeam Fortress 2\tValve\tValve\t\t813122\t56073\t0\t50,000,000 .. 100,000,000\t11858\t1769\t348\t367\t0\t0\t0\t82571\n',
#   '304930\tUnturned\tSmartly Dressed Games\tSmartly Dressed Games\t\t438411\t40925\t0\t20,000,000 .. 50,000,000\t10750\t3927\t331\t817\t0\t0\t0\t50423\n',
#   '271590\tGrand Theft Auto V\tRockstar North\tRockstar Games\t\t1144201\t208030\t0\t20,000,000 .. 50,000,000\t13182\t813\t6094\t178\t4497\t5997\t25\t109264\n',
#   '550\tLeft 4 Dead 2\tValve\tValve\t\t600580\t15752\t0\t20,000,000 .. 50,000,000\t1864\t204\t518\t121\t999\t999\t0\t20819\n',
#   '230410\tWarframe\tDigital Extremes\tDigital Extremes\t\t437656\t47546\t0\t20,000,000 .. 50,000,000\t8948\t1314\t348\t573\t0\t0\t0\t50453\n',
#   '105600\tTerraria\tRe-Logic\tRe-Logic\t\t941388\t20346\t0\t20,000,000 .. 50,000,000\t6346\t858\t1801\t121\t999\t999\t0\t39371\n',
#   '570\tfalse\tJul 9, 2013\n',
#   '730\tfalse\tAug 21, 2012\n',
#   '578080\tfalse\tDec 21, 2017\n',
#   '1063730\tfalse\tSep 28, 2021\n',
#   '440\tfalse\tOct 10, 2007\n',
#   '304930\tfalse\tJul 7, 2017\n',
#   '271590\tfalse\tApr 13, 2015\n',
#   '550\tfalse\tNov 16, 2009\n',
#   '230410\tfalse\tMar 25, 2013\n',
#   '105600\tfalse\tMay 16, 2011\n'],
#  ['SLF4J: Class path contains multiple SLF4J bindings.\n',
#   'SLF4J: Found binding in [jar:file:/opt/hive/lib/log4j-slf4j-impl-2.10.0.jar!/org/slf4j/impl/StaticLoggerBinder.class]\n',
#   'SLF4J: Found binding in [jar:file:/opt/hadoop-3.3.1/share/hadoop/common/lib/slf4j-log4j12-1.7.30.jar!/org/slf4j/impl/StaticLoggerBinder.class]\n',
#   'SLF4J: See http://www.slf4j.org/codes.html#multiple_bindings for an explanation.\n',
#   'SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]\n',
#   'Hive Session ID = 2ce0fdb7-5104-4ab2-8aab-5cac84cae668\n',
#   '\n',
#   'Logging initialized using configuration in file:/opt/hive/conf/hive-log4j2.properties Async: true\n',
#   'Hive Session ID = b822918b-853d-49cc-9d87-a7e396f0558e\n',
#   'OK\n',
#   'Time taken: 0.475 seconds\n',
#   'OK\n',
#   'Time taken: 0.025 seconds\n',
#   'OK\n',
#   'Time taken: 0.048 seconds\n',
#   'OK\n',
#   'Time taken: 0.248 seconds\n',
#   'Loading data to table steamdb.steam_store_raw\n',
#   'OK\n',
#   'Time taken: 1.07 seconds\n',
#   'OK\n',
#   'Time taken: 0.012 seconds\n',
#   'OK\n',
#   'Time taken: 0.03 seconds\n',
#   'Query ID = root_20230602162913_0c9c0c77-917a-4d42-80ee-42bb843b7bba\n',
#   'Total jobs = 3\n',
#   'Launching Job 1 out of 3\n',
#   'Number of reduce tasks determined at compile time: 1\n',
#   'In order to change the average load for a reducer (in bytes):\n',
#   '  set hive.exec.reducers.bytes.per.reducer=<number>\n',
#   'In order to limit the maximum number of reducers:\n',
#   '  set hive.exec.reducers.max=<number>\n',
#   'In order to set a constant number of reducers:\n',
#   '  set mapreduce.job.reduces=<number>\n',
#   'Starting Job = job_1685723246432_0001, Tracking URL = http://resourcemanager:8088/proxy/application_1685723246432_0001/\n',
#   'Kill Command = /opt/hadoop-3.3.1/bin/mapred job  -kill job_1685723246432_0001\n',
#   'Hadoop job information for Stage-1: number of mappers: 3; number of reducers: 1\n',
#   '2023-06-02 16:29:18,670 Stage-1 map = 0%,  reduce = 0%\n',
#   '2023-06-02 16:29:27,816 Stage-1 map = 33%,  reduce = 0%, Cumulative CPU 7.78 sec\n',
#   '2023-06-02 16:29:28,831 Stage-1 map = 67%,  reduce = 0%, Cumulative CPU 15.45 sec\n',
#   '2023-06-02 16:29:31,875 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 19.45 sec\n',
#   '2023-06-02 16:29:32,894 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 20.76 sec\n',
#   'MapReduce Total cumulative CPU time: 20 seconds 760 msec\n',
#   'Ended Job = job_1685723246432_0001\n',
#   'Stage-4 is filtered out by condition resolver.\n',
#   'Stage-3 is selected by condition resolver.\n',
#   'Stage-5 is filtered out by condition resolver.\n',
#   'Launching Job 3 out of 3\n',
#   "Number of reduce tasks is set to 0 since there's no reduce operator\n",
#   'Starting Job = job_1685723246432_0002, Tracking URL = http://resourcemanager:8088/proxy/application_1685723246432_0002/\n',
#   'Kill Command = /opt/hadoop-3.3.1/bin/mapred job  -kill job_1685723246432_0002\n',
#   'Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 0\n',
#   '2023-06-02 16:29:42,488 Stage-3 map = 0%,  reduce = 0%\n',
#   '2023-06-02 16:29:46,549 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 1.17 sec\n',
#   'MapReduce Total cumulative CPU time: 1 seconds 170 msec\n',
#   'Ended Job = job_1685723246432_0002\n',
#   'Loading data to table steamdb.steam_store\n',
#   'MapReduce Jobs Launched: \n',
#   'Stage-Stage-1: Map: 3  Reduce: 1   Cumulative CPU: 20.76 sec   HDFS Read: 579223545 HDFS Write: 1357748 SUCCESS\n',
#   'Stage-Stage-3: Map: 1   Cumulative CPU: 1.17 sec   HDFS Read: 1358771 HDFS Write: 1355592 SUCCESS\n',
#   'Total MapReduce CPU Time Spent: 21 seconds 930 msec\n',
#   'OK\n',
#   'Time taken: 35.796 seconds\n',
#   'OK\n',
#   'Time taken: 0.012 seconds\n',
#   'OK\n',
#   'Time taken: 0.028 seconds\n',
#   'Loading data to table steamdb.steam_spy_raw\n',
#   'OK\n',
#   'Time taken: 0.113 seconds\n',
#   'OK\n',
#   'Time taken: 0.014 seconds\n',
#   'OK\n',
#   'Time taken: 0.032 seconds\n',
#   'Query ID = root_20230602162949_32aa1147-f54d-4d7f-b69c-60b05368a8e8\n',
#   'Total jobs = 3\n',
#   'Launching Job 1 out of 3\n',
#   'Number of reduce tasks determined at compile time: 1\n',
#   'In order to change the average load for a reducer (in bytes):\n',
#   '  set hive.exec.reducers.bytes.per.reducer=<number>\n',
#   'In order to limit the maximum number of reducers:\n',
#   '  set hive.exec.reducers.max=<number>\n',
#   'In order to set a constant number of reducers:\n',
#   '  set mapreduce.job.reduces=<number>\n',
#   'Starting Job = job_1685723246432_0003, Tracking URL = http://resourcemanager:8088/proxy/application_1685723246432_0003/\n',
#   'Kill Command = /opt/hadoop-3.3.1/bin/mapred job  -kill job_1685723246432_0003\n',
#   'Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1\n',
#   '2023-06-02 16:29:56,701 Stage-1 map = 0%,  reduce = 0%\n',
#   '2023-06-02 16:30:01,771 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 3.62 sec\n',
#   '2023-06-02 16:30:05,821 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 5.08 sec\n',
#   'MapReduce Total cumulative CPU time: 5 seconds 80 msec\n',
#   'Ended Job = job_1685723246432_0003\n',
#   'Stage-4 is selected by condition resolver.\n',
#   'Stage-3 is filtered out by condition resolver.\n',
#   'Stage-5 is filtered out by condition resolver.\n',
#   'Moving data to directory hdfs://namenode:9000/user/hive/warehouse/steamdb.db/steam_spy/.hive-staging_hive_2023-06-02_16-29-49_100_5310248937778986233-1/-ext-10000\n',
#   'Loading data to table steamdb.steam_spy\n',
#   'MapReduce Jobs Launched: \n',
#   'Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 5.08 sec   HDFS Read: 20078229 HDFS Write: 5279654 SUCCESS\n',
#   'Total MapReduce CPU Time Spent: 5 seconds 80 msec\n',
#   'OK\n',
#   'Time taken: 17.877 seconds\n',
#   'OK\n',
#   'Time taken: 0.653 seconds, Fetched: 10 row(s)\n',
#   'OK\n',
#   'Time taken: 0.053 seconds, Fetched: 10 row(s)\n',
#   'OK\n',
#   'Time taken: 0.009 seconds\n',
#   'OK\n',
#   'Time taken: 0.025 seconds\n',
#   'Query ID = root_20230602163007_bed0deb4-cee6-4cc2-8a2c-327f8229d580\n',
#   'Total jobs = 2\n',
#   '\n',
#   '\n',
#   '\n',
#   'SLF4J: Actual binding is of type [org.apache.logging.slf4j.Log4jLoggerFactory]Execution log at: /tmp/root/root_20230602163007_bed0deb4-cee6-4cc2-8a2c-327f8229d580.log\n',
#   '\n',
#   '2023-06-02 16:30:12\tDump the side-table for tag: 0 with group count: 51922 into file: file:/tmp/root/2ce0fdb7-5104-4ab2-8aab-5cac84cae668/hive_2023-06-02_16-30-07_758_7010728765818211466-1/-local-10003/HashTable-Stage-5/MapJoin-mapfile00--.hashtable\n',
#   '2023-06-02 16:30:12\tEnd of local task; Time Taken: 0.948 sec.\n',
#   'Execution completed successfully\n',
#   'MapredLocal task succeeded\n',
#   'Launching Job 1 out of 2\n',
#   "Number of reduce tasks is set to 0 since there's no reduce operator\n",
#   'Starting Job = job_1685723246432_0004, Tracking URL = http://resourcemanager:8088/proxy/application_1685723246432_0004/\n',
#   'Kill Command = /opt/hadoop-3.3.1/bin/mapred job  -kill job_1685723246432_0004\n',
#   'Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 0\n',
#   '2023-06-02 16:30:17,328 Stage-5 map = 0%,  reduce = 0%\n',
#   '2023-06-02 16:30:21,425 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 2.9 sec\n',
#   'MapReduce Total cumulative CPU time: 2 seconds 900 msec\n',
#   'Ended Job = job_1685723246432_0004\n',
#   'Loading data to table steamdb.steam_joined\n',
#   'Launching Job 2 out of 2\n',
#   'Number of reduce tasks determined at compile time: 1\n',
#   'In order to change the average load for a reducer (in bytes):\n',
#   '  set hive.exec.reducers.bytes.per.reducer=<number>\n',
#   'In order to limit the maximum number of reducers:\n',
#   '  set hive.exec.reducers.max=<number>\n',
#   'In order to set a constant number of reducers:\n',
#   '  set mapreduce.job.reduces=<number>\n',
#   'Starting Job = job_1685723246432_0005, Tracking URL = http://resourcemanager:8088/proxy/application_1685723246432_0005/\n',
#   'Kill Command = /opt/hadoop-3.3.1/bin/mapred job  -kill job_1685723246432_0005\n',
#   'Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1\n',
#   '2023-06-02 16:30:30,981 Stage-3 map = 0%,  reduce = 0%\n',
#   '2023-06-02 16:30:35,042 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 0.84 sec\n',
#   '2023-06-02 16:30:39,098 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 2.08 sec\n',
#   'MapReduce Total cumulative CPU time: 2 seconds 80 msec\n',
#   'Ended Job = job_1685723246432_0005\n',
#   'MapReduce Jobs Launched: \n',
#   'Stage-Stage-5: Map: 1   Cumulative CPU: 2.9 sec   HDFS Read: 5280746 HDFS Write: 3173892 SUCCESS\n',
#   'Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 2.08 sec   HDFS Read: 19279 HDFS Write: 5491 SUCCESS\n',
#   'Total MapReduce CPU Time Spent: 4 seconds 980 msec\n',
#   'OK\n',
#   'Time taken: 33.445 seconds\n'])

# %%
run_in_hive("hive -f /data/master_volume/hive_scripts/steam_01_combine_show.hql")
